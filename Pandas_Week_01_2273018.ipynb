# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.5.3
# 1.23.5

# %%
# Menyertakan Prefix dan Suffix pada seluruh Kolom Pandas Data Frame
n_rows = 5
n_cols = 5
cols= tuple('ABCDE')
df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)),
                  columns=cols)

df
# Out:
#    A  B  C  D  E
# 0  6  8  6  9  1
# 1  8  3  4  4  4
# 2  9  8  8  1  6
# 3  9  4  4  1  8
# 4  6  4  9  4  7

# %%
tuple('ABCDE')
# Out:
# ('A', 'B', 'C', 'D', 'E')

# %%
df.add_prefix('kolom_')
# Out:
#    kolom_A  kolom_B  kolom_C  kolom_D  kolom_E
# 0        6        8        6        9        1
# 1        8        3        4        4        4
# 2        9        8        8        1        6
# 3        9        4        4        1        8
# 4        6        4        9        4        7

# %%
df.add_suffix('_field')
# Out:
#    A_field  B_field  C_field  D_field  E_field
# 0        6        8        6        9        1
# 1        8        3        4        4        4
# 2        9        8        8        1        6
# 3        9        4        4        1        8
# 4        6        4        9        4        7

# %%
# Pemilihan baris (rows selection) pada Data Frame
n_rows = 10
n_cols = 5
cols= tuple('ABCDE')
df = pd.DataFrame(np.random.randint(1, 5, size=(n_rows, n_cols)),
                  columns=cols)

df
# Out:
#    A  B  C  D  E
# 0  1  2  3  3  1
# 1  2  1  3  1  2
# 2  1  3  2  1  2
# 3  4  1  2  4  3
# 4  3  2  2  3  2
# 5  4  3  4  4  4
# 6  2  3  2  1  4
# 7  4  1  4  2  2
# 8  1  4  4  3  4
# 9  3  4  1  3  4

# %%
df[(df['A'] == 1) | (df['A'] == 3)]
# Out:
#    A  B  C  D  E
# 0  1  2  3  3  1
# 2  1  3  2  1  2
# 4  3  2  2  3  2
# 8  1  4  4  3  4
# 9  3  4  1  3  4

# %%
df[df['A']. isin([1, 3])]
# Out:
#    A  B  C  D  E
# 0  1  2  3  3  1
# 2  1  3  2  1  2
# 4  3  2  2  3  2
# 8  1  4  4  3  4
# 9  3  4  1  3  4

# %%
df[~df['A' ].isin([1, 3])]
# Out:
#    A  B  C  D  E
# 1  2  1  3  1  2
# 3  4  1  2  4  3
# 5  4  3  4  4  4
# 6  2  3  2  1  4
# 7  4  1  4  2  2

# %%
# Konversi tipe data String ke Numerik pada kolom Data Frame
data = {'coll': ['1', '2', '3', 'teks'],
        'col2': ['1', '2', '3', '4']}

df = pd.DataFrame (data)
df
# Out:
#    coll col2
# 0     1    1
# 1     2    2
# 2     3    3
# 3  teks    4

# %%
 df.dtypes
# Out:
# coll    object
# col2    object
# dtype: object

# %%
df_x = df.astype({'col2':'int'})
df_x
# Out:
#    coll  col2
# 0     1     1
# 1     2     2
# 2     3     3
# 3  teks     4

# %%
df_x.dtypes
# Out:
# coll    object
# col2     int64
# dtype: object

# %%
df.apply(pd.to_numeric, errors='coerce')
# Out:
#    coll  col2
# 0   1.0     1
# 1   2.0     2
# 2   3.0     3
# 3   NaN     4

# %%
# Pemilihan kolom (columns selection) pada Pandas Data Frame berdasarkan tipe data
n_rows = 5
n_cols = 2
cols= ['bil pecahan', 'bil_bulat']

df = pd. DataFrame (np.random.randint(1, 20, size=(n_rows, n_cols)),
                    columns=cols)
df ['bil pecahan'] = df['bil pecahan'].astype('float')

df.index= pd.util.testing.makeDateIndex(n_rows, freq='H')
df = df.reset_index()

df['teks'] = list('ABCDE')

df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/__init__.py:16: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#                 index  bil pecahan  bil_bulat teks
# 0 2000-01-01 00:00:00          2.0          6    A
# 1 2000-01-01 01:00:00         17.0         19    B
# 2 2000-01-01 02:00:00         19.0          3    C
# 3 2000-01-01 03:00:00          7.0          2    D
# 4 2000-01-01 04:00:00          3.0          4    E

# %%
df.dtypes
# Out:
# index          datetime64[ns]
# bil pecahan           float64
# bil_bulat               int64
# teks                   object
# dtype: object

# %%
df.select_dtypes(include='number')
# Out:
#    bil pecahan  bil_bulat
# 0          2.0          6
# 1         17.0         19
# 2         19.0          3
# 3          7.0          2
# 4          3.0          4

# %%
df.select_dtypes(include='float')
# Out:
#    bil pecahan
# 0          2.0
# 1         17.0
# 2         19.0
# 3          7.0
# 4          3.0

# %%
df.select_dtypes(include='int')
# Out:
#    bil_bulat
# 0          6
# 1         19
# 2          3
# 3          2
# 4          4

# %%
df.select_dtypes(include='object')
# Out:
#   teks
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E

# %%
df.select_dtypes(include='datetime')
# Out:
#                 index
# 0 2000-01-01 00:00:00
# 1 2000-01-01 01:00:00
# 2 2000-01-01 02:00:00
# 3 2000-01-01 03:00:00
# 4 2000-01-01 04:00:00

# %%
df.select_dtypes(include=['number','object'])
# Out:
#    bil pecahan  bil_bulat teks
# 0          2.0          6    A
# 1         17.0         19    B
# 2         19.0          3    C
# 3          7.0          2    D
# 4          3.0          4    E
