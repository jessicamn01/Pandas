# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.5.3
# 1.23.5

# %%
# Resampling pada data deret waktu
n_rows = 365 * 24
n_cols = 2
cols= ['col1', 'col2']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)),
                  columns=cols)
df.index = pd.util.testing.makeDateIndex(n_rows, freq='H')

df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/__init__.py:16: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#                      col1  col2
# 2000-01-01 00:00:00    11    16
# 2000-01-01 01:00:00     3     2
# 2000-01-01 02:00:00     5     2
# 2000-01-01 03:00:00    17     5
# 2000-01-01 04:00:00    16    12
# ...                   ...   ...
# 2000-12-30 19:00:00     5    19
# 2000-12-30 20:00:00    19     1
# 2000-12-30 21:00:00     9    14
# 2000-12-30 22:00:00    16    19
# 2000-12-30 23:00:00     5     5
#
# [8760 rows x 2 columns]

# %%
df.resample('M')['col1'].sum().to_frame()
# Out:
#             col1
# 2000-01-31  7566
# 2000-02-29  6882
# 2000-03-31  7428
# 2000-04-30  7430
# 2000-05-31  7687
# 2000-06-30  6995
# 2000-07-31  7646
# 2000-08-31  7372
# 2000-09-30  7299
# 2000-10-31  7545
# 2000-11-30  7101
# 2000-12-31  7017

# %%
df.resample('D')['col1'].sum().to_frame()
# Out:
#             col1
# 2000-01-01   256
# 2000-01-02   210
# 2000-01-03   256
# 2000-01-04   221
# 2000-01-05   304
# ...          ...
# 2000-12-26   256
# 2000-12-27   264
# 2000-12-28   225
# 2000-12-29   228
# 2000-12-30   203
#
# [365 rows x 1 columns]

# %%
# Membentuk dummy Data Frame
pd.DataFrame({'col1':[1,2,3,4],
             'col2':[5,6,7,7]})
# Out:
#    col1  col2
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     7

# %%
n_rows = 5
n_cols = 3

arr = np.random.randint(1, 20, size=(n_rows, n_cols))
arr
# Out:
# array([[ 9,  6,  3],
#        [11, 16, 17],
#        [ 9, 10, 10],
#        [ 3, 15,  9],
#        [ 3, 18,  4]])

# %%
pd.DataFrame (arr, columns=tuple('ABC'))
# Out:
#     A   B   C
# 0   9   6   3
# 1  11  16  17
# 2   9  10  10
# 3   3  15   9
# 4   3  18   4

# %%
pd.util.testing.makeDataFrame().head()
# Out:
#                    A         B         C         D
# cPsBuTf0C1 -1.025861 -0.042173  1.125038  0.146636
# ZWk1m5enMs -0.414387 -0.201086  0.976757 -1.331926
# TLRLboIW2g  0.708039  0.017195  0.977869 -0.263069
# 9iitVzDuhG -0.194986 -2.045930  1.658312 -0.479950
# Nnfmkj0x1i -0.863397  2.790500 -0.016693  0.132033

# %%
pd.util.testing.makeMixedDataFrame().head()
# Out:
#      A    B     C          D
# 0  0.0  0.0  foo1 2009-01-01
# 1  1.0  1.0  foo2 2009-01-02
# 2  2.0  0.0  foo3 2009-01-05
# 3  3.0  1.0  foo4 2009-01-06
# 4  4.0  0.0  foo5 2009-01-07

# %%
pd.util.testing.makeTimeDataFrame().head()
# Out:
#                    A         B         C         D
# 2000-01-03 -0.394577  0.012022  0.448159  1.161017
# 2000-01-04 -0.499965  2.292334 -0.145652  0.888793
# 2000-01-05  0.231923 -1.152769  1.185138 -1.296375
# 2000-01-06 -1.096753  0.947446  0.599665 -1.899396
# 2000-01-07  0.007126  0.132101  0.689306 -0.609508

# %%
pd.util.testing.makeMissingDataframe().head()
# Out:
#                    A         B         C         D
# 9W3r6k7e7i -0.090550 -0.056113 -0.174399 -1.210932
# OBiaOPDNQR -0.254931 -1.983987       NaN -1.316376
# teQLpQiZ5X  1.353082 -1.007583 -1.199722  0.155342
# 5tVO6CbAfm  0.770925 -1.143050 -0.427701 -0.438102
# UMv2jROf4h -0.514707 -1.280450 -1.350327  1.497892

# %%
#  Formatting tampilan Data Frame
n_rows= 5
n_cols = 2
cols = ['omset', 'operasional']

df = pd. DataFrame (np.random.randint (1, 20, size=(n_rows, n_cols)),
                    columns=cols)

df
# Out:
#    omset  operasional
# 0      2            5
# 1     14            3
# 2     12           11
# 3      7            2
# 4     10           17

# %%
df ['omset'] = df ['omset'] * 100_000
df ['operasional'] = df ['operasional'] * 10_000
df
# Out:
#      omset  operasional
# 0   200000        50000
# 1  1400000        30000
# 2  1200000       110000
# 3   700000        20000
# 4  1000000       170000

# %%
df.index = pd.util.testing.makeDateIndex (n_rows, freq='D')
df = df.reset_index ()
df = df.rename (columns={'index': 'tanggal'})
df
# Out:
#      tanggal    omset  operasional
# 0 2000-01-01   200000        50000
# 1 2000-01-02  1400000        30000
# 2 2000-01-03  1200000       110000
# 3 2000-01-04   700000        20000
# 4 2000-01-05  1000000       170000

# %%
formatku = {'tanggal':'{:%d/%m/%y}',
            'operasional': 'Rp {:.2f}',
            'omset': 'Rp {:.2f} '}
laporan = df.style.format (formatku)
laporan
# Out:
# <style type="text/css">
# </style>
# <table id="T_82637" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82637_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_82637_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_82637_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82637_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82637_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_82637_row0_col1" class="data row0 col1" >Rp 200000.00 </td>
#       <td id="T_82637_row0_col2" class="data row0 col2" >Rp 50000.00</td>
#     </tr>
#     <tr>
#       <th id="T_82637_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_82637_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_82637_row1_col1" class="data row1 col1" >Rp 1400000.00 </td>
#       <td id="T_82637_row1_col2" class="data row1 col2" >Rp 30000.00</td>
#     </tr>
#     <tr>
#       <th id="T_82637_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_82637_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_82637_row2_col1" class="data row2 col1" >Rp 1200000.00 </td>
#       <td id="T_82637_row2_col2" class="data row2 col2" >Rp 110000.00</td>
#     </tr>
#     <tr>
#       <th id="T_82637_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_82637_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_82637_row3_col1" class="data row3 col1" >Rp 700000.00 </td>
#       <td id="T_82637_row3_col2" class="data row3 col2" >Rp 20000.00</td>
#     </tr>
#     <tr>
#       <th id="T_82637_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_82637_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_82637_row4_col1" class="data row4 col1" >Rp 1000000.00 </td>
#       <td id="T_82637_row4_col2" class="data row4 col2" >Rp 170000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
type (laporan)
# Out:
# pandas.io.formats.style.Styler

# %%
laporan.hide_index()
# Out:
# <ipython-input-17-f1e1dc65f3f0>:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   laporan.hide_index()
# <style type="text/css">
# </style>
# <table id="T_82637" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_82637_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_82637_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_82637_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_82637_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_82637_row0_col1" class="data row0 col1" >Rp 200000.00 </td>
#       <td id="T_82637_row0_col2" class="data row0 col2" >Rp 50000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_82637_row1_col1" class="data row1 col1" >Rp 1400000.00 </td>
#       <td id="T_82637_row1_col2" class="data row1 col2" >Rp 30000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_82637_row2_col1" class="data row2 col1" >Rp 1200000.00 </td>
#       <td id="T_82637_row2_col2" class="data row2 col2" >Rp 110000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_82637_row3_col1" class="data row3 col1" >Rp 700000.00 </td>
#       <td id="T_82637_row3_col2" class="data row3 col2" >Rp 20000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_82637_row4_col1" class="data row4 col1" >Rp 1000000.00 </td>
#       <td id="T_82637_row4_col2" class="data row4 col2" >Rp 170000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
laporan.set_caption ('Data Omset dan Operasional')
# Out:
# <style type="text/css">
# </style>
# <table id="T_82637" class="dataframe">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th id="T_82637_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_82637_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_82637_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_82637_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_82637_row0_col1" class="data row0 col1" >Rp 200000.00 </td>
#       <td id="T_82637_row0_col2" class="data row0 col2" >Rp 50000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_82637_row1_col1" class="data row1 col1" >Rp 1400000.00 </td>
#       <td id="T_82637_row1_col2" class="data row1 col2" >Rp 30000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_82637_row2_col1" class="data row2 col1" >Rp 1200000.00 </td>
#       <td id="T_82637_row2_col2" class="data row2 col2" >Rp 110000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_82637_row3_col1" class="data row3 col1" >Rp 700000.00 </td>
#       <td id="T_82637_row3_col2" class="data row3 col2" >Rp 20000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_82637_row4_col1" class="data row4 col1" >Rp 1000000.00 </td>
#       <td id="T_82637_row4_col2" class="data row4 col2" >Rp 170000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
laporan.highlight_min('omset', color='pink')
laporan.highlight_max('omset', color='lightgreen')

laporan.highlight_min('operasional', color='lightblue')
laporan.highlight_max('operasional', color='grey')
# Out:
# <style type="text/css">
# #T_82637_row0_col1 {
#   background-color: pink;
# }
# #T_82637_row1_col1 {
#   background-color: lightgreen;
# }
# #T_82637_row3_col2 {
#   background-color: lightblue;
# }
# #T_82637_row4_col2 {
#   background-color: grey;
# }
# </style>
# <table id="T_82637" class="dataframe">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th id="T_82637_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_82637_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_82637_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_82637_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_82637_row0_col1" class="data row0 col1" >Rp 200000.00 </td>
#       <td id="T_82637_row0_col2" class="data row0 col2" >Rp 50000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_82637_row1_col1" class="data row1 col1" >Rp 1400000.00 </td>
#       <td id="T_82637_row1_col2" class="data row1 col2" >Rp 30000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_82637_row2_col1" class="data row2 col1" >Rp 1200000.00 </td>
#       <td id="T_82637_row2_col2" class="data row2 col2" >Rp 110000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_82637_row3_col1" class="data row3 col1" >Rp 700000.00 </td>
#       <td id="T_82637_row3_col2" class="data row3 col2" >Rp 20000.00</td>
#     </tr>
#     <tr>
#       <td id="T_82637_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_82637_row4_col1" class="data row4 col1" >Rp 1000000.00 </td>
#       <td id="T_82637_row4_col2" class="data row4 col2" >Rp 170000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Menggabungkan dua Data Frame secara berdampingan
d1 = {'coll' :[1, 2, 3],
      'co12': [10, 20, 30]}
df1 = pd. DataFrame (d1)
df1
# Out:
#    coll  co12
# 0     1    10
# 1     2    20
# 2     3    30

# %%
d2 = {'co13': [4, 5, 6],
      'co14': [40, 50, 60] }
df2 = pd.DataFrame (d2)
df2
# Out:
#    co13  co14
# 0     4    40
# 1     5    50
# 2     6    60

# %%
df = pd.merge (df1, df2, left_index=True, right_index=True)
df
# Out:
#    coll  co12  co13  co14
# 0     1    10     4    40
# 1     2    20     5    50
# 2     3    30     6    60
