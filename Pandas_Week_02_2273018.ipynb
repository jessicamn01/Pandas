# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.5.3
# 1.23.5

# %%
# Membalik urutan baris dan kolom pada Data Frame
n_rows = 5
n_cols = 5
cols= tuple('ABCDE')
df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)),
                  columns=cols)

df
# Out:
#    A  B  C  D  E
# 0  9  5  8  5  6
# 1  6  8  1  6  1
# 2  2  6  9  7  2
# 3  5  7  9  6  9
# 4  9  9  4  1  6

# %%
df.loc[:, ::-1]
# Out:
#    E  D  C  B  A
# 0  6  5  8  5  9
# 1  1  6  1  8  6
# 2  2  7  9  6  2
# 3  9  6  9  7  5
# 4  6  1  4  9  9

# %%
df.loc[::-1]
# Out:
#    A  B  C  D  E
# 4  9  9  4  1  6
# 3  5  7  9  6  9
# 2  2  6  9  7  2
# 1  6  8  1  6  1
# 0  9  5  8  5  6

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  9  9  4  1  6
# 1  5  7  9  6  9
# 2  2  6  9  7  2
# 3  6  8  1  6  1
# 4  9  5  8  5  6

# %%
# Mengganti nama kolom pada Data Frame
n_rows = 5
n_cols = 5
cols= tuple('ABCDE')
df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)),
                  columns=cols)

df
# Out:
#    A  B  C  D  E
# 0  5  2  4  9  8
# 1  2  4  5  3  7
# 2  4  5  1  2  7
# 3  9  1  7  4  7
# 4  8  9  3  5  7

# %%
df.rename(columns={'C': 'Hobi' })
# Out:
#    A  B  Hobi  D  E
# 0  5  2     4  9  8
# 1  2  4     5  3  7
# 2  4  5     1  2  7
# 3  9  1     7  4  7
# 4  8  9     3  5  7

# %%
df.rename(columns={'A': 'Nama', 'B': 'Alamat', 'D': 'Kota'})
# Out:
#    Nama  Alamat  C  Kota  E
# 0     5       2  4     9  8
# 1     2       4  5     3  7
# 2     4       5  1     2  7
# 3     9       1  7     4  7
# 4     8       9  3     5  7

# %%
# Menghapus missing values pada Data Frame
df = pd.util.testing.makeMissingDataframe().reset_index()
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/__init__.py:16: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#         index         A         B         C         D
# 0  RmpiYJ3M1V -1.287604  0.573741 -0.124947 -0.224568
# 1  cEXTUQXdx1 -0.559451  0.014619  0.508511  0.973345
# 2  ymyt6ABKWi  0.288905  0.371170  0.167009  1.239396
# 3  MnOscBB6wR -0.413013  0.377581  0.647315 -0.500722
# 4  TRouMfF8wl -0.084240       NaN  3.052039 -0.769988

# %%
df = df.rename(columns={'index': 'Z'})
df.head()
# Out:
#             Z         A         B         C         D
# 0  RmpiYJ3M1V -1.287604  0.573741 -0.124947 -0.224568
# 1  cEXTUQXdx1 -0.559451  0.014619  0.508511  0.973345
# 2  ymyt6ABKWi  0.288905  0.371170  0.167009  1.239396
# 3  MnOscBB6wR -0.413013  0.377581  0.647315 -0.500722
# 4  TRouMfF8wl -0.084240       NaN  3.052039 -0.769988

# %%
df_backup = df.copy(deep=True)

# %%
df = df.dropna(axis='columns')
df.head()
# Out:
#             Z
# 0  RmpiYJ3M1V
# 1  cEXTUQXdx1
# 2  ymyt6ABKWi
# 3  MnOscBB6wR
# 4  TRouMfF8wl

# %%
df = df_backup.copy(deep=True)
df = df.dropna(axis='rows')
df.head()
# Out:
#             Z         A         B         C         D
# 0  RmpiYJ3M1V -1.287604  0.573741 -0.124947 -0.224568
# 1  cEXTUQXdx1 -0.559451  0.014619  0.508511  0.973345
# 2  ymyt6ABKWi  0.288905  0.371170  0.167009  1.239396
# 3  MnOscBB6wR -0.413013  0.377581  0.647315 -0.500722
# 5  i3yvZ4sZeq  1.584729  1.679219  0.181491  1.367583

# %%
df = df_backup.copy(deep=True)
df.isna().mean()
# Out:
# Z    0.000000
# A    0.100000
# B    0.166667
# C    0.100000
# D    0.033333
# dtype: float64

# %%
treshold = len(df)* 0.9
df = df.dropna(thresh=treshold, axis='columns')
df.head()
# Out:
#             Z         A         C         D
# 0  RmpiYJ3M1V -1.287604 -0.124947 -0.224568
# 1  cEXTUQXdx1 -0.559451  0.508511  0.973345
# 2  ymyt6ABKWi  0.288905  0.167009  1.239396
# 3  MnOscBB6wR -0.413013  0.647315 -0.500722
# 4  TRouMfF8wl -0.084240  3.052039 -0.769988

# %%
#  Memeriksa kesamaan antar kolom (Series) pada Data Frame
data = {'A': [15, 15, 18,  np. nan, 12],
        'B': [15, 15, 18, np. nan, 12]}
df = pd.DataFrame(data)
df
# Out:
#       A     B
# 0  15.0  15.0
# 1  15.0  15.0
# 2  18.0  18.0
# 3   NaN   NaN
# 4  12.0  12.0

# %%
df['A']
# Out:
# 0    15.0
# 1    15.0
# 2    18.0
# 3     NaN
# 4    12.0
# Name: A, dtype: float64

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['A'] == df ['B']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df['A'] == df ['B']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
dfl = df.copy(deep=True)
df.equals(dfl)
# Out:
# True

# %%
df == dfl
# Out:
#        A      B
# 0   True   True
# 1   True   True
# 2   True   True
# 3  False  False
# 4   True   True
