# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.5.3
# 1.23.5

# %%
# Membalik urutan baris dan kolom pada Data Frame
n_rows = 5
n_cols = 5
cols= tuple('ABCDE')
df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)),
                  columns=cols)

df
# Out:
#    A  B  C  D  E
# 0  7  5  2  9  5
# 1  2  1  5  9  6
# 2  9  7  7  2  5
# 3  5  8  6  1  9
# 4  4  2  1  9  8

# %%
df.loc[:, ::-1]
# Out:
#    E  D  C  B  A
# 0  5  9  2  5  7
# 1  6  9  5  1  2
# 2  5  2  7  7  9
# 3  9  1  6  8  5
# 4  8  9  1  2  4

# %%
df.loc[::-1]
# Out:
#    A  B  C  D  E
# 4  4  2  1  9  8
# 3  5  8  6  1  9
# 2  9  7  7  2  5
# 1  2  1  5  9  6
# 0  7  5  2  9  5

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  4  2  1  9  8
# 1  5  8  6  1  9
# 2  9  7  7  2  5
# 3  2  1  5  9  6
# 4  7  5  2  9  5

# %%
# Mengganti nama kolom pada Data Frame
n_rows = 5
n_cols = 5
cols= tuple('ABCDE')
df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)),
                  columns=cols)

df
# Out:
#    A  B  C  D  E
# 0  5  1  8  4  1
# 1  7  8  1  6  8
# 2  2  2  3  6  7
# 3  8  2  6  6  2
# 4  8  9  6  5  1

# %%
df.rename(columns={'C': 'Hobi' })
# Out:
#    A  B  Hobi  D  E
# 0  5  1     8  4  1
# 1  7  8     1  6  8
# 2  2  2     3  6  7
# 3  8  2     6  6  2
# 4  8  9     6  5  1

# %%
df.rename(columns={'A': 'Nama', 'B': 'Alamat', 'D': 'Kota'})
# Out:
#    Nama  Alamat  C  Kota  E
# 0     5       1  8     4  1
# 1     7       8  1     6  8
# 2     2       2  3     6  7
# 3     8       2  6     6  2
# 4     8       9  6     5  1

# %%
# Menghapus missing values pada Data Frame
df = pd.util.testing.makeMissingDataframe().reset_index()
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/__init__.py:16: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#         index         A         B         C         D
# 0  ziwMYo6ctB  0.168890  1.005113       NaN       NaN
# 1  F9Sv1wT6Wk -0.824446  0.377387 -0.066425 -0.135111
# 2  uuFyTHGGIi  0.699337  1.330127 -1.437410       NaN
# 3  3MMS7ynar9 -0.375367  0.291554 -1.628401 -1.780746
# 4  wZuFQ7udFY -0.283013 -0.328218 -0.329439  1.152809

# %%
df = df.rename(columns={'index': 'Z'})
df.head()
# Out:
#             Z         A         B         C         D
# 0  ziwMYo6ctB  0.168890  1.005113       NaN       NaN
# 1  F9Sv1wT6Wk -0.824446  0.377387 -0.066425 -0.135111
# 2  uuFyTHGGIi  0.699337  1.330127 -1.437410       NaN
# 3  3MMS7ynar9 -0.375367  0.291554 -1.628401 -1.780746
# 4  wZuFQ7udFY -0.283013 -0.328218 -0.329439  1.152809

# %%
df_backup = df.copy(deep=True)

# %%
df = df.dropna(axis='columns')
df.head()
# Out:
#             Z
# 0  ziwMYo6ctB
# 1  F9Sv1wT6Wk
# 2  uuFyTHGGIi
# 3  3MMS7ynar9
# 4  wZuFQ7udFY

# %%
df = df_backup.copy(deep=True)
df = df.dropna(axis='rows')
df.head()
# Out:
#              Z         A         B         C         D
# 1   F9Sv1wT6Wk -0.824446  0.377387 -0.066425 -0.135111
# 3   3MMS7ynar9 -0.375367  0.291554 -1.628401 -1.780746
# 4   wZuFQ7udFY -0.283013 -0.328218 -0.329439  1.152809
# 7   90KAUdl9sR -0.146161 -0.323757 -1.222497 -0.513728
# 10  bZPZ3mW5iZ  0.663566 -1.323014 -1.306227  1.280961

# %%
df = df_backup.copy(deep=True)
df.isna().mean()
# Out:
# Z    0.000000
# A    0.033333
# B    0.133333
# C    0.100000
# D    0.133333
# dtype: float64

# %%
treshold = len(df)* 0.9
df = df.dropna(thresh=treshold, axis='columns')
df.head()
# Out:
#             Z         A         C
# 0  ziwMYo6ctB  0.168890       NaN
# 1  F9Sv1wT6Wk -0.824446 -0.066425
# 2  uuFyTHGGIi  0.699337 -1.437410
# 3  3MMS7ynar9 -0.375367 -1.628401
# 4  wZuFQ7udFY -0.283013 -0.329439

# %%
#  Memeriksa kesamaan antar kolom (Series) pada Data Frame
data = {'A': [15, 15, 18,  np. nan, 12],
        'B': [15, 15, 18, np. nan, 12]}
df = pd.DataFrame(data)
df
# Out:
#       A     B
# 0  15.0  15.0
# 1  15.0  15.0
# 2  18.0  18.0
# 3   NaN   NaN
# 4  12.0  12.0

# %%
df['A']
# Out:
# 0    15.0
# 1    15.0
# 2    18.0
# 3     NaN
# 4    12.0
# Name: A, dtype: float64

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['A'] == df ['B']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df['A'] == df ['B']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
dfl = df.copy(deep=True)
df.equals(dfl)
# Out:
# True

# %%
df == dfl
# Out:
#        A      B
# 0   True   True
# 1   True   True
# 2   True   True
# 3  False  False
# 4   True   True
